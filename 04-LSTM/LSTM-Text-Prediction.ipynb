# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Embedding

# Sample text data (training corpus)
text_data = [
    "i love machine learning",
    "i love deep learning",
    "machine learning is amazing",
    "deep learning is powerful",
    "rnn is great for sequence data",
    "tensorflow helps with deep learning",
    "artificial intelligence is the future",
    "deep learning powers modern AI",
    "neural networks can recognize patterns",
    "data science relies on machine learning",
    "supervised learning needs labeled data",
    "unsupervised learning finds hidden patterns",
    "reinforcement learning improves decision making",
    "python is great for machine learning",
    "tensorflow makes deep learning easier",
    "keras simplifies neural network development",
    "pytorch is popular among researchers",
    "scikit learn is useful for data science",
    "matplotlib helps visualize data",
    "self driving cars use deep learning",
    "natural language processing helps chatbots",
    "speech recognition converts voice to text",
    "computer vision detects objects in images",
    "AI recommends movies based on preferences"
]

# Tokenize words (convert words to numbers)
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text_data)
total_words = len(tokenizer.word_index) + 1  # +1 for padding token

# Create input sequences
input_sequences = []
for line in text_data:
    tokens = tokenizer.texts_to_sequences([line])[0]  # Convert sentence to numbers
    for i in range(1, len(tokens)):
        input_sequences.append(tokens[:i+1])  # Create sequences of increasing length

# Pad sequences to the same length
max_sequence_length = max(len(seq) for seq in input_sequences)
input_sequences = pad_sequences(input_sequences, maxlen=max_sequence_length, padding='pre')

# Split inputs (X) and outputs (y)
X, y = input_sequences[:, :-1], input_sequences[:, -1]

# Convert labels to categorical (one-hot encoding)
y = tf.keras.utils.to_categorical(y, num_classes=total_words)

# Build the LSTM model
model = Sequential([
    Embedding(total_words, 10, input_length=max_sequence_length-1),  # Embedding layer
    LSTM(50, activation='relu'),  # LSTM layer with 50 units
    Dense(total_words, activation='softmax')  # Output layer (predict next word)
])

# Compile model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
model.fit(X, y, epochs=100, verbose=1)

# Function to predict the next word
def predict_next_word(seed_text):
    sequence = tokenizer.texts_to_sequences([seed_text])[0]
    sequence = pad_sequences([sequence], maxlen=max_sequence_length-1, padding='pre')
    predicted_index = np.argmax(model.predict(sequence))
    for word, index in tokenizer.word_index.items():
        if index == predicted_index:
            return word
    return "?"

# Try predicting next words
seed_text = "machine learning"
next_word = predict_next_word(seed_text)
print(f"'{seed_text}' → '{seed_text} {next_word}'")

seed_text = "deep learning"
next_word = predict_next_word(seed_text)
print(f"'{seed_text}' → '{seed_text} {next_word}'")
# Out:
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 38ms/step - accuracy: 0.0182 - loss: 4.4065
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.1362 - loss: 4.4026
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.1352 - loss: 4.3993
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.1445 - loss: 4.3950
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.1362 - loss: 4.3913
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.1393 - loss: 4.3851
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.1478 - loss: 4.3779
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.1093 - loss: 4.3721
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.1395 - loss: 4.3620
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.1166 - loss: 4.3520
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.1416 - loss: 4.3236
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.1166 - loss: 4.3019
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.1458 - loss: 4.2561
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.1291 - loss: 4.1899
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.1218 - loss: 4.0969
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.1322 - loss: 3.9611
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.1176 - loss: 3.9815
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.1228 - loss: 3.8838
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.1176 - loss: 3.9182
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.1447 - loss: 3.8364
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.1541 - loss: 3.8473
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.1385 - loss: 3.8597
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.1353 - loss: 3.8821
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.1270 - loss: 3.8188
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.1207 - loss: 3.8640
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.1332 - loss: 3.8397
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.1166 - loss: 3.8415
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.1510 - loss: 3.7521
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.1270 - loss: 3.7996
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.1520 - loss: 3.7449
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.1260 - loss: 3.8175
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.1228 - loss: 3.8626
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.1145 - loss: 3.7879
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.1301 - loss: 3.7274
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.1353 - loss: 3.7751
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.1197 - loss: 3.7599
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.1416 - loss: 3.6772
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.1353 - loss: 3.6832
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.1197 - loss: 3.7254
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.1352 - loss: 3.6592
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.1445 - loss: 3.6950
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.1477 - loss: 3.6220
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.1383 - loss: 3.6195
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.1393 - loss: 3.6339
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.1609 - loss: 3.5970
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.1352 - loss: 3.5957
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.1609 - loss: 3.5849
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.1598 - loss: 3.5607
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.1670 - loss: 3.5007
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.1918 - loss: 3.4729
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.1843 - loss: 3.4547
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.1967 - loss: 3.3999
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.1758 - loss: 3.4042
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.2027 - loss: 3.3765
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.1782 - loss: 3.2873
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.1720 - loss: 3.3191
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.1814 - loss: 3.2972
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.1906 - loss: 3.1926
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.1696 - loss: 3.2442
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.2029 - loss: 3.1062
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.2163 - loss: 3.0693
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.2007 - loss: 3.0086
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.2029 - loss: 2.9126
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.2257 - loss: 2.8997
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.2184 - loss: 2.8201
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.2616 - loss: 2.7234
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.2385 - loss: 2.7298
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.2667 - loss: 2.6616
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.2481 - loss: 2.5990
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.2997 - loss: 2.6607
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.2837 - loss: 2.5136
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.2521 - loss: 2.4501
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.2743 - loss: 2.4755
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.3537 - loss: 2.3980
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.3155 - loss: 2.3465
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.3301 - loss: 2.2430
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.3235 - loss: 2.2778
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.3612 - loss: 2.2432
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.3292 - loss: 2.1530
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.4583 - loss: 2.0767
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.4263 - loss: 2.0377
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.4210 - loss: 2.0208
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3852 - loss: 2.0524
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.4746 - loss: 1.9426
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.4295 - loss: 1.9893
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.4665 - loss: 1.8501
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.4515 - loss: 1.8747
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.4472 - loss: 1.7929
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.4816 - loss: 1.8027
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.4780 - loss: 1.8619
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5167 - loss: 1.7598
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.4983 - loss: 1.6612
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5070 - loss: 1.6829
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5215 - loss: 1.6445
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5275 - loss: 1.6456
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5294 - loss: 1.6695
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.5872 - loss: 1.5280
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5749 - loss: 1.5204
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.4851 - loss: 1.5104
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.4929 - loss: 1.5006
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 855ms/step
# 'machine learning' → 'machine learning is'
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 'deep learning' → 'deep learning is'
